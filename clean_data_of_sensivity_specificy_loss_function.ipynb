# %%
# !git clone https://github.com/twpkevin06222/Liver-Segmentation-Project-.git medical_imaging
# Out:
# Cloning into 'medical_imaging'...
# remote: Enumerating objects: 581, done.
# remote: Total 581 (delta 0), reused 0 (delta 0), pack-reused 581
# Receiving objects: 100% (581/581), 299.41 MiB | 14.49 MiB/s, done.
# Resolving deltas: 100% (181/181), done.
# Updating files: 100% (119/119), done.

# %%
# !pip install nibabel
# Out:
# Requirement already satisfied: nibabel in /usr/local/lib/python3.10/dist-packages (4.0.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from nibabel) (1.23.5)
# Requirement already satisfied: packaging>=17.0 in /usr/local/lib/python3.10/dist-packages (from nibabel) (23.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from nibabel) (67.7.2)

# %%
import h5py
import os
import cv2
from keras.layers import Input,Dense,Flatten,Dropout,Reshape,Conv2D,MaxPooling2D,UpSampling2D,Conv2DTranspose
from keras.layers import Activation
from keras.layers import BatchNormalization
from keras.models import Model,Sequential
from keras.callbacks import ModelCheckpoint
from keras.optimizers import Adadelta, RMSprop,SGD,Adam
from keras import regularizers
from keras import backend as K
import numpy as np
import scipy.misc
import numpy.random as rng
from PIL import Image, ImageDraw, ImageFont
from sklearn.utils import shuffle
import nibabel as nib #reading nifti images
import math
import glob
import matplotlib.pyplot as plt
# %matplotlib inline
#from read_data import load_images
from keras.layers import concatenate
from keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from scipy.spatial.distance import directed_hausdorff

# %%
import tensorflow as tf
import keras
print('Tensorflow version:', tf.__version__)
print('Keras version:', keras.__version__)
# Out:
# Tensorflow version: 2.12.0
# Keras version: 2.12.0

# %%
def three_to_two(path, label='FALSE'):
    ff = sorted(glob.glob(path))
    images =[]
    for f in range(len(ff)):
        a = nib.load(ff[f])
        a = a.get_data()
        for i in range(a.shape[2]):
            images.append(a[:,:,i])
    images = np.asarray(images)
    #images = images.reshape(-1, 128,128, 1) # dimension to feed into the network
    return images

def min_max_norm(images):
    m = np.max(images)
    mi = np.min(images)
    images = (images - mi)/ (m - mi)
    return images

def label_outliers(img_labels):
    img_labels[img_labels>1]=1
    img_labels[img_labels<0]=0
    return img_labels

#Image for training
images = three_to_two(path='medical_imaging/tmp/tmp_img/img_new/*')
x_data = min_max_norm(images)

#labels
img_labels = three_to_two(path='medical_imaging/tmp/tmp_img/img_new_label/*')
y_data = label_outliers(img_labels)

#Test Image
img_test = three_to_two(path='medical_imaging/tmp/tmp_img/test_img/*')
x_test = min_max_norm(img_test)

#Test Labels
label_test = three_to_two(path='medical_imaging/tmp/tmp_img/test_img_label/*')
y_test = label_outliers(label_test)
# Out:
# <ipython-input-5-281133919471>:6: DeprecationWarning: get_data() is deprecated in favor of get_fdata(), which has a more predictable return type. To obtain get_data() behavior going forward, use numpy.asanyarray(img.dataobj).
#
# * deprecated from version: 3.0
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 5.0
#   a = a.get_data()

# %%
#show 1st 20 slices with noisy y_data_noisy
for i in range(20):
    fig, ax = plt.subplots(1,4, figsize = (8,4))
    ax[0].imshow(x_data[i], cmap='gray')
    ax[1].imshow(y_data[i], cmap='gray') # Use y_data_noisy here to show the noisy labels
    ax[2].imshow(x_test[i], cmap='gray')
    ax[3].imshow(y_test[i], cmap='gray')

plt.show()

# %%
x_data = x_data[:,:,:,np.newaxis] # same as reshape (-1,128,128,1)
y_data = y_data[:,:,:,np.newaxis]
x_test = x_test[:,:,:,np.newaxis]
y_test = y_test[:,:,:,np.newaxis]

print('Dimension for training data:', x_data.shape)
print('Dimension for training data labels:', y_data.shape)
print('Dimension for test data:', x_test.shape)
print('Dimension for test data labels:', y_test.shape)
# Out:
# Dimension for training data: (3036, 128, 128, 1)
# Dimension for training data labels: (3036, 128, 128, 1)
# Dimension for test data: (735, 128, 128, 1)
# Dimension for test data labels: (735, 128, 128, 1)

# %%
from sklearn.utils import shuffle

x_train, x_val, y_train, y_val = train_test_split(x_data, y_data, test_size = 0.2, random_state =42)
x_test, y_test = shuffle(x_test, y_test, random_state= 42)

# %%
import keras.backend as K
import tensorflow as tf

def dice_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + K.epsilon()) / (K.sum(y_true_f) + K.sum(y_pred_f) + K.epsilon())

def jaccard_index(y_true, y_pred):
    intersection = K.sum(y_true * y_pred)
    union = K.sum(y_true) + K.sum(y_pred) - intersection
    return (intersection + K.epsilon()) / (union + K.epsilon())

def precision(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    return true_positives / (predicted_positives + K.epsilon())

def recall(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    total_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    return true_positives / (total_positives + K.epsilon())

def hausdorff_distance(y_true, y_pred):
    surface_distances = tf.reduce_sum(y_true * y_pred, axis=[1, 2]) / tf.reduce_sum(y_true + y_pred, axis=[1, 2])
    hausdorff_distance = tf.reduce_max(surface_distances)
    return hausdorff_distance

def specificity(y_true, y_pred):
    true_negatives = K.sum(K.round(K.clip((1 - y_true) * (1 - y_pred), 0, 1)))
    total_negatives = K.sum(K.round(K.clip(1 - y_true, 0, 1)))
    return true_negatives / (total_negatives + K.epsilon())

def sensitivity(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    total_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    return true_positives / (total_positives + K.epsilon())


def sensitivity_specificity_loss(y_true, y_pred, beta=1):
    # Sensitivity = TP / (TP + FN)
    sensitivity = K.sum(y_true * y_pred) / (K.sum(y_true) + K.epsilon())

    # Specificity = TN / (TN + FP)
    specificity = K.sum((1 - y_true) * (1 - y_pred)) / (K.sum(1 - y_true) + K.epsilon())

    # Calculate sensitivity-specificity loss
    loss = 1 - (sensitivity**beta) * (specificity**(1 / beta))

    return loss

# %%
input_layer = Input(shape=x_train.shape[1:]) #Input(shape = (x, y, inChannel))

# %%
def conv_block(x_in, filters, batch_norm, kernel_size=(3,3)):
    x = Conv2D(filters, kernel_size, padding='same')(x_in)
    if batch_norm=='TRUE':
        x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Conv2D(filters, kernel_size, padding='same')(x)
    if batch_norm=='TRUE':
        x = BatchNormalization()(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    return x

def conv_2d(x_in, filters, batch_norm, kernel_size=(3,3),acti ='relu'):
    x = Conv2D(filters, kernel_size, padding='same')(x_in)
    if batch_norm=='TRUE':
        x=BatchNormalization()(x)
    x= Activation(acti)(x)
    return x

def pool(x_in, pool_size=(2, 2), type='Max'):
    if type=='Max':
        p = MaxPooling2D(pool_size)(x_in)
    return p

def up(x_in, filters, merge, batch_norm, size=(2,2)):
    u = UpSampling2D(size)(x_in)
    conv = conv_block(u, filters, batch_norm)
    merge=concatenate([merge, conv],axis=-1)
    return merge

def Unet_01(input_layer):
    conv1 = conv_block(input_layer, filters=16, batch_norm='TRUE')
    pool1 = pool(conv1)

    conv2 = conv_block(pool1, filters=32, batch_norm='TRUE')
    pool2 = pool(conv2)

    conv3 = conv_block(pool2, filters=32, batch_norm='TRUE')
    pool3 = pool(conv3)

    conv4 = conv_block(pool3, filters=64, batch_norm='TRUE')
    pool4 = pool(conv4)

    conv5 = conv_2d(pool4, filters=128, batch_norm='TRUE')

    up1 = up(conv5,filters=128, merge=conv4, batch_norm='TRUE')
    conv6 = conv_2d(up1, filters=128, batch_norm='TRUE')

    up2 = up(conv6, filters=128, merge=conv3, batch_norm='TRUE')
    conv7 = conv_2d(up2, filters=128, batch_norm='TRUE')

    up3 = up(conv7, filters=64, merge=conv2, batch_norm='TRUE')
    conv8 = conv_2d(up3, filters=64, batch_norm='TRUE')

    up4 = up(conv8, filters=32, merge=conv1, batch_norm='TRUE')
    conv9 = conv_2d(up4, filters=32, batch_norm='TRUE')

    conv10 = conv_2d(conv9, filters=1, batch_norm='FALSE', acti='sigmoid')

    output_layer = conv10
    model = Model(input_layer, output_layer)

    return model

# %%
model = Unet_01(input_layer)

# %%
def my_generator(x_train, y_train, batch_size):
    data_generator = ImageDataGenerator(
            width_shift_range=0.1,
            height_shift_range=0.1,
            rotation_range=10,
            zoom_range=0.1).flow(x_train, x_train, batch_size, seed=42)
    mask_generator = ImageDataGenerator(
            width_shift_range=0.1,
            height_shift_range=0.1,
            rotation_range=10,
            zoom_range=0.1).flow(y_train, y_train, batch_size, seed=42)
    while True:
        x_batch, _ = data_generator.next()
        y_batch, _ = mask_generator.next()
        yield x_batch, y_batch

# %%
image_batch, mask_batch = next(my_generator(x_train, y_train, 8))
fix, ax = plt.subplots(8,2, figsize=(8,20))
for i in range(8):
    ax[i,0].imshow(image_batch[i,:,:,0], cmap='gray')
    ax[i,1].imshow(mask_batch[i,:,:,0], cmap='gray')
plt.show()

# %%
model.compile(optimizer=Adam(1e-4), loss= sensitivity_specificity_loss, metrics=[dice_coef,jaccard_index,hausdorff_distance,precision,recall,specificity,sensitivity])

# %%
# def steps_per_epoch(sample, batch_size):
#     a = int(np.floor(sample/batch_size))
#     if a<200:
#         return 200
#     else:
#         return a

sample = len(x_data)
batch_size = 64
epochs = 20
steps_per_epoch = 200
#steps_per_epoch = int(np.floor(sample/batch_size))
#steps_per_epoch = steps_per_epoch(sample, batch_size)

print('Step per epoch: ', steps_per_epoch)
# Out:
# Step per epoch:  200

# %%
from keras.callbacks import LearningRateScheduler
weight_saver = ModelCheckpoint('seg.h5', monitor='val_dice_coef',
                                              save_best_only=True, save_weights_only=True)

lr_decay = LearningRateScheduler(lambda x: 1e-3 * 0.8 ** x)

# %%
# Assuming you have your dataset, batch size, and total number of samples
batch_size = 64
total_samples = len(x_train)  # Replace with the actual number of training samples

# Calculate steps_per_epoch
steps_per_epoch = np.ceil(total_samples / batch_size)
hist = model.fit_generator(my_generator(x_train, y_train, batch_size),
                           steps_per_epoch = steps_per_epoch,
                           validation_data = (x_val, y_val),
                           epochs=epochs, verbose=1,
                           callbacks = [weight_saver, lr_decay])
# Out:
# <ipython-input-21-1da3efee21a0>:7: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   hist = model.fit_generator(my_generator(x_train, y_train, batch_size),
# Epoch 1/20
# 38/38 [==============================] - 50s 746ms/step - loss: 0.1928 - dice_coef: 0.4871 - jaccard_index: 0.3362 - hausdorff_distance: 0.3830 - precision: 0.5290 - recall: 0.9728 - specificity: 0.9130 - sensitivity: 0.9728 - val_loss: 0.9209 - val_dice_coef: 0.1303 - val_jaccard_index: 0.0698 - val_hausdorff_distance: 0.1742 - val_precision: 0.0675 - val_recall: 0.9998 - val_specificity: 0.0424 - val_sensitivity: 0.9998 - lr: 0.0010
# Epoch 2/20
# 38/38 [==============================] - 14s 365ms/step - loss: 0.0564 - dice_coef: 0.7506 - jaccard_index: 0.6042 - hausdorff_distance: 0.4574 - precision: 0.7085 - recall: 0.9866 - specificity: 0.9728 - sensitivity: 0.9866 - val_loss: 0.6362 - val_dice_coef: 0.1686 - val_jaccard_index: 0.0922 - val_hausdorff_distance: 0.2056 - val_precision: 0.0892 - val_recall: 0.9856 - val_specificity: 0.3037 - val_sensitivity: 0.9856 - lr: 8.0000e-04
# Epoch 3/20
# 38/38 [==============================] - 14s 364ms/step - loss: 0.0391 - dice_coef: 0.8138 - jaccard_index: 0.6883 - hausdorff_distance: 0.4668 - precision: 0.7553 - recall: 0.9908 - specificity: 0.9789 - sensitivity: 0.9908 - val_loss: 0.4591 - val_dice_coef: 0.3006 - val_jaccard_index: 0.1774 - val_hausdorff_distance: 0.2947 - val_precision: 0.6260 - val_recall: 0.7968 - val_specificity: 0.9663 - val_sensitivity: 0.7968 - lr: 6.4000e-04
# Epoch 4/20
# 38/38 [==============================] - 15s 384ms/step - loss: 0.0332 - dice_coef: 0.8465 - jaccard_index: 0.7348 - hausdorff_distance: 0.4712 - precision: 0.7884 - recall: 0.9915 - specificity: 0.9821 - sensitivity: 0.9915 - val_loss: 0.3511 - val_dice_coef: 0.3830 - val_jaccard_index: 0.2376 - val_hausdorff_distance: 0.3373 - val_precision: 0.5573 - val_recall: 0.8831 - val_specificity: 0.9512 - val_sensitivity: 0.8831 - lr: 5.1200e-04
# Epoch 5/20
# 38/38 [==============================] - 14s 375ms/step - loss: 0.0279 - dice_coef: 0.8640 - jaccard_index: 0.7614 - hausdorff_distance: 0.4740 - precision: 0.8060 - recall: 0.9938 - specificity: 0.9842 - sensitivity: 0.9938 - val_loss: 0.5242 - val_dice_coef: 0.4589 - val_jaccard_index: 0.2991 - val_hausdorff_distance: 0.3899 - val_precision: 0.8574 - val_recall: 0.4486 - val_specificity: 0.9944 - val_sensitivity: 0.4486 - lr: 4.0960e-04
# Epoch 6/20
# 38/38 [==============================] - 14s 361ms/step - loss: 0.0276 - dice_coef: 0.8667 - jaccard_index: 0.7656 - hausdorff_distance: 0.4757 - precision: 0.8039 - recall: 0.9938 - specificity: 0.9839 - sensitivity: 0.9938 - val_loss: 0.3478 - val_dice_coef: 0.6012 - val_jaccard_index: 0.4313 - val_hausdorff_distance: 0.4225 - val_precision: 0.7349 - val_recall: 0.6780 - val_specificity: 0.9826 - val_sensitivity: 0.6780 - lr: 3.2768e-04
# Epoch 7/20
# 38/38 [==============================] - 14s 378ms/step - loss: 0.0245 - dice_coef: 0.8805 - jaccard_index: 0.7871 - hausdorff_distance: 0.4758 - precision: 0.8228 - recall: 0.9946 - specificity: 0.9859 - sensitivity: 0.9946 - val_loss: 0.3485 - val_dice_coef: 0.6314 - val_jaccard_index: 0.4631 - val_hausdorff_distance: 0.4351 - val_precision: 0.7108 - val_recall: 0.6635 - val_specificity: 0.9809 - val_sensitivity: 0.6635 - lr: 2.6214e-04
# Epoch 8/20
# 38/38 [==============================] - 14s 360ms/step - loss: 0.0229 - dice_coef: 0.8864 - jaccard_index: 0.7963 - hausdorff_distance: 0.4775 - precision: 0.8290 - recall: 0.9954 - specificity: 0.9864 - sensitivity: 0.9954 - val_loss: 0.2758 - val_dice_coef: 0.6751 - val_jaccard_index: 0.5112 - val_hausdorff_distance: 0.4467 - val_precision: 0.6785 - val_recall: 0.7462 - val_specificity: 0.9750 - val_sensitivity: 0.7462 - lr: 2.0972e-04
# Epoch 9/20
# 38/38 [==============================] - 14s 371ms/step - loss: 0.0220 - dice_coef: 0.8897 - jaccard_index: 0.8018 - hausdorff_distance: 0.4770 - precision: 0.8327 - recall: 0.9957 - specificity: 0.9869 - sensitivity: 0.9957 - val_loss: 0.2607 - val_dice_coef: 0.7054 - val_jaccard_index: 0.5465 - val_hausdorff_distance: 0.4553 - val_precision: 0.7014 - val_recall: 0.7584 - val_specificity: 0.9773 - val_sensitivity: 0.7584 - lr: 1.6777e-04
# Epoch 10/20
# 38/38 [==============================] - 14s 366ms/step - loss: 0.0213 - dice_coef: 0.8927 - jaccard_index: 0.8068 - hausdorff_distance: 0.4779 - precision: 0.8361 - recall: 0.9960 - specificity: 0.9871 - sensitivity: 0.9960 - val_loss: 0.1964 - val_dice_coef: 0.7306 - val_jaccard_index: 0.5770 - val_hausdorff_distance: 0.4620 - val_precision: 0.6793 - val_recall: 0.8276 - val_specificity: 0.9726 - val_sensitivity: 0.8276 - lr: 1.3422e-04
# Epoch 11/20
# 38/38 [==============================] - 14s 363ms/step - loss: 0.0216 - dice_coef: 0.8926 - jaccard_index: 0.8066 - hausdorff_distance: 0.4781 - precision: 0.8347 - recall: 0.9958 - specificity: 0.9870 - sensitivity: 0.9958 - val_loss: 0.1291 - val_dice_coef: 0.7423 - val_jaccard_index: 0.5919 - val_hausdorff_distance: 0.4692 - val_precision: 0.6488 - val_recall: 0.9048 - val_specificity: 0.9658 - val_sensitivity: 0.9048 - lr: 1.0737e-04
# Epoch 12/20
# 38/38 [==============================] - 14s 359ms/step - loss: 0.0204 - dice_coef: 0.8955 - jaccard_index: 0.8113 - hausdorff_distance: 0.4779 - precision: 0.8383 - recall: 0.9964 - specificity: 0.9873 - sensitivity: 0.9964 - val_loss: 0.1932 - val_dice_coef: 0.7806 - val_jaccard_index: 0.6412 - val_hausdorff_distance: 0.4659 - val_precision: 0.7668 - val_recall: 0.8230 - val_specificity: 0.9826 - val_sensitivity: 0.8230 - lr: 8.5899e-05
# Epoch 13/20
# 38/38 [==============================] - 14s 362ms/step - loss: 0.0200 - dice_coef: 0.8973 - jaccard_index: 0.8144 - hausdorff_distance: 0.4781 - precision: 0.8412 - recall: 0.9965 - specificity: 0.9877 - sensitivity: 0.9965 - val_loss: 0.1111 - val_dice_coef: 0.8181 - val_jaccard_index: 0.6930 - val_hausdorff_distance: 0.4702 - val_precision: 0.7642 - val_recall: 0.9093 - val_specificity: 0.9804 - val_sensitivity: 0.9093 - lr: 6.8719e-05
# Epoch 14/20
# 38/38 [==============================] - 14s 361ms/step - loss: 0.0198 - dice_coef: 0.9013 - jaccard_index: 0.8206 - hausdorff_distance: 0.4785 - precision: 0.8473 - recall: 0.9963 - specificity: 0.9881 - sensitivity: 0.9963 - val_loss: 0.1305 - val_dice_coef: 0.8396 - val_jaccard_index: 0.7243 - val_hausdorff_distance: 0.4701 - val_precision: 0.8223 - val_recall: 0.8835 - val_specificity: 0.9867 - val_sensitivity: 0.8835 - lr: 5.4976e-05
# Epoch 15/20
# 38/38 [==============================] - 14s 362ms/step - loss: 0.0196 - dice_coef: 0.9017 - jaccard_index: 0.8212 - hausdorff_distance: 0.4786 - precision: 0.8471 - recall: 0.9964 - specificity: 0.9881 - sensitivity: 0.9964 - val_loss: 0.0788 - val_dice_coef: 0.8704 - val_jaccard_index: 0.7709 - val_hausdorff_distance: 0.4706 - val_precision: 0.8344 - val_recall: 0.9356 - val_specificity: 0.9871 - val_sensitivity: 0.9356 - lr: 4.3980e-05
# Epoch 16/20
# 38/38 [==============================] - 14s 363ms/step - loss: 0.0195 - dice_coef: 0.9016 - jaccard_index: 0.8210 - hausdorff_distance: 0.4786 - precision: 0.8464 - recall: 0.9965 - specificity: 0.9880 - sensitivity: 0.9965 - val_loss: 0.0479 - val_dice_coef: 0.8948 - val_jaccard_index: 0.8098 - val_hausdorff_distance: 0.4747 - val_precision: 0.8548 - val_recall: 0.9659 - val_specificity: 0.9886 - val_sensitivity: 0.9659 - lr: 3.5184e-05
# Epoch 17/20
# 38/38 [==============================] - 14s 373ms/step - loss: 0.0191 - dice_coef: 0.9032 - jaccard_index: 0.8238 - hausdorff_distance: 0.4785 - precision: 0.8491 - recall: 0.9967 - specificity: 0.9883 - sensitivity: 0.9967 - val_loss: 0.0408 - val_dice_coef: 0.9029 - val_jaccard_index: 0.8232 - val_hausdorff_distance: 0.4761 - val_precision: 0.8643 - val_recall: 0.9724 - val_specificity: 0.9894 - val_sensitivity: 0.9724 - lr: 2.8147e-05
# Epoch 18/20
# 38/38 [==============================] - 14s 364ms/step - loss: 0.0189 - dice_coef: 0.9034 - jaccard_index: 0.8242 - hausdorff_distance: 0.4791 - precision: 0.8491 - recall: 0.9969 - specificity: 0.9883 - sensitivity: 0.9969 - val_loss: 0.0258 - val_dice_coef: 0.9081 - val_jaccard_index: 0.8318 - val_hausdorff_distance: 0.4766 - val_precision: 0.8602 - val_recall: 0.9882 - val_specificity: 0.9889 - val_sensitivity: 0.9882 - lr: 2.2518e-05
# Epoch 19/20
# 38/38 [==============================] - 14s 372ms/step - loss: 0.0191 - dice_coef: 0.9020 - jaccard_index: 0.8219 - hausdorff_distance: 0.4788 - precision: 0.8469 - recall: 0.9968 - specificity: 0.9882 - sensitivity: 0.9968 - val_loss: 0.0219 - val_dice_coef: 0.9124 - val_jaccard_index: 0.8390 - val_hausdorff_distance: 0.4778 - val_precision: 0.8651 - val_recall: 0.9917 - val_specificity: 0.9893 - val_sensitivity: 0.9917 - lr: 1.8014e-05
# Epoch 20/20
# 38/38 [==============================] - 14s 362ms/step - loss: 0.0189 - dice_coef: 0.9043 - jaccard_index: 0.8256 - hausdorff_distance: 0.4789 - precision: 0.8503 - recall: 0.9968 - specificity: 0.9883 - sensitivity: 0.9968 - val_loss: 0.0236 - val_dice_coef: 0.9119 - val_jaccard_index: 0.8383 - val_hausdorff_distance: 0.4777 - val_precision: 0.8657 - val_recall: 0.9899 - val_specificity: 0.9894 - val_sensitivity: 0.9899 - lr: 1.4412e-05

# %%
from keras.callbacks import TensorBoard
import time
batch_size = 64
epochs = 20
model_dir = 'logs/{}'.format(time.strftime("%H"+"%M"))
tensorboard = TensorBoard(log_dir= model_dir, histogram_freq=epochs, batch_size=batch_size, write_graph=True,
                          write_grads=False, write_images=True, embeddings_freq=0,
                          embeddings_layer_names=None, embeddings_metadata=None,
                          embeddings_data=None, update_freq='epoch')

write_time = time.strftime("%H"+"%M")
# Out:
# WARNING:tensorflow:`batch_size` is no longer needed in the `TensorBoard` Callback and will be ignored in TensorFlow 2.0.

# %%
model.load_weights('seg.h5')

# %%
plt.plot(hist.history['lr'], color='b')
plt.xlabel("epochs")
plt.ylabel("Learning Rate")
plt.grid(linestyle='dotted')
plt.show()

# %%
import matplotlib.pyplot as plt

# Assuming you have the history dictionary that contains the metric values during training
# hist = model.fit(...)

# Plot Loss
plt.figure(figsize=(10, 5))
plt.plot(hist.history['loss'], color='b', label='Training Loss')
plt.plot(hist.history['val_loss'], color='r', label='Validation Loss')
plt.legend(loc='upper right')
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.grid(linestyle='dotted')
plt.title("Training and Validation Loss")
plt.show()

# Plot Metrics
plt.figure(figsize=(10, 5))
plt.plot(hist.history['dice_coef'], color='b', label='Dice Coefficient')
plt.plot(hist.history['jaccard_index'], color='g', label='Jaccard Index')
plt.plot(hist.history['precision'], color='y', label='Precision')
plt.plot(hist.history['recall'], color='orange', label='Recall')
plt.plot(hist.history['hausdorff_distance'], color='purple', label='Hausdorff Distance')
plt.plot(hist.history['specificity'], color='magenta', label='Specificity')
plt.plot(hist.history['sensitivity'], color='cyan', label='Sensitivity')

plt.xlabel("Epochs")
plt.ylabel("Metric Value")
plt.legend(loc='lower right')
plt.grid(linestyle='dotted')
plt.title("Evaluation Metrics")
plt.show()

# %%
# To run tensorboard
print('To view tensorboard, put this in your command line: \n tensorboard --log=logs/{}/'.format(write_time))
# Out:
# To view tensorboard, put this in your command line:
#  tensorboard --log=logs/1305/

# %%
# !rm -rf ngrok-stable-linux-amd64.zip
# !rm -rf ngrok
# !wget https://bin.equinox.io/c/4VmDzA7iaHb/ngrok-stable-linux-amd64.zip
# !unzip ngrok-stable-linux-amd64.zip
#!rm -f log/*   # Delete this if you want to keep the logs of the old runs
LOG_DIR = 'logs/{}'.format(write_time)
get_ipython().system_raw(
    'tensorboard --logdir {} --host 0.0.0.0 --port 6006 &'
    .format(LOG_DIR)
)
get_ipython().system_raw('./ngrok http 6006 &')
! curl -s http://localhost:4040/api/tunnels | python3 -c \
    "import sys, json; print(json.load(sys.stdin)['tunnels'][0]['public_url'])"
# Out:
# --2023-08-27 13:19:00--  https://bin.equinox.io/c/4VmDzA7iaHb/ngrok-stable-linux-amd64.zip
# Resolving bin.equinox.io (bin.equinox.io)... 18.205.222.128, 54.161.241.46, 52.202.168.65, ...
# Connecting to bin.equinox.io (bin.equinox.io)|18.205.222.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 13921656 (13M) [application/octet-stream]
# Saving to: ‘ngrok-stable-linux-amd64.zip’
#
# ngrok-stable-linux- 100%[===================>]  13.28M  4.79MB/s    in 2.8s
#
# 2023-08-27 13:19:03 (4.79 MB/s) - ‘ngrok-stable-linux-amd64.zip’ saved [13921656/13921656]
#
# Archive:  ngrok-stable-linux-amd64.zip
#   inflating: ngrok
# Traceback (most recent call last):
#   File "<string>", line 1, in <module>
#   File "/usr/lib/python3.10/json/__init__.py", line 293, in load
#     return loads(fp.read(),
#   File "/usr/lib/python3.10/json/__init__.py", line 346, in loads
#     return _default_decoder.decode(s)
#   File "/usr/lib/python3.10/json/decoder.py", line 337, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#   File "/usr/lib/python3.10/json/decoder.py", line 355, in raw_decode
#     raise JSONDecodeError("Expecting value", s, err.value) from None
# json.decoder.JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
# Assuming you have already defined the evaluation functions as mentioned in previous interactions

# Evaluating the model on the test dataset
test_eval = model.evaluate(x_test, y_test, verbose=1, batch_size=batch_size)

# Extracting individual metrics from the test evaluation
test_loss = test_eval[0]
test_dice_coef = test_eval[1]
test_jaccard_index = jaccard_index(y_test, model.predict(x_test))
test_precision = precision(y_test, model.predict(x_test))
test_recall = recall(y_test, model.predict(x_test))
test_hausdorff_distance = hausdorff_distance(y_test, model.predict(x_test))
test_specificity = specificity(y_test, model.predict(x_test))
test_sensitivity = sensitivity(y_test, model.predict(x_test))

# Printing the evaluation results
print('Test loss:', test_loss)
print('Test Dice Coefficient:', test_dice_coef)
print('Test Jaccard Index:', test_jaccard_index)
print('Test Precision:', test_precision)
print('Test Recall:', test_recall)
print('Test Hausdorff Distance:', test_hausdorff_distance)
print('Test Specificity:', test_specificity)
print('Test Sensitivity:', test_sensitivity)
# Out:
# 12/12 [==============================] - 4s 284ms/step - loss: 0.9187 - dice_coef: 0.1140 - jaccard_index: 0.0605 - hausdorff_distance: 0.1634 - precision: 0.0585 - recall: 0.9997 - specificity: 0.0452 - sensitivity: 0.9997
# 23/23 [==============================] - 2s 50ms/step
# 23/23 [==============================] - 1s 48ms/step
# 23/23 [==============================] - 1s 54ms/step
# 23/23 [==============================] - 1s 45ms/step
# 23/23 [==============================] - 1s 46ms/step
# 23/23 [==============================] - 1s 45ms/step
# Test loss: 0.9186679720878601
# Test Dice Coefficient: 0.11401774734258652
# Test Jaccard Index: tf.Tensor(0.060597673, shape=(), dtype=float32)
# Test Precision: tf.Tensor(0.058618706, shape=(), dtype=float32)
# Test Recall: tf.Tensor(0.99973077, shape=(), dtype=float32)
# Test Hausdorff Distance: tf.Tensor(0.1699427, shape=(), dtype=float32)
# Test Specificity: tf.Tensor(0.04523119, shape=(), dtype=float32)
# Test Sensitivity: tf.Tensor(0.99973077, shape=(), dtype=float32)

# %%
y_pred = model.predict(x_test)
for i in range(0,20,2):
    fig, ax = plt.subplots(1,3,figsize=(12,6))
    ax[0].imshow(x_test[i,:,:,0], cmap='gray')
    ax[1].imshow(y_test[i,:,:,0], cmap='viridis')
    ax[2].imshow(y_pred[i,:,:,0], cmap='viridis')
plt.show()
# Out:
# 23/23 [==============================] - 1s 45ms/step

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 128, 128, 1  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 128, 128, 16  160         ['input_1[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 128, 128, 16  64         ['conv2d[0][0]']
#  alization)                     )
#
#  activation (Activation)        (None, 128, 128, 16  0           ['batch_normalization[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 128, 128, 16  2320        ['activation[0][0]']
#                                 )
#
#  batch_normalization_1 (BatchNo  (None, 128, 128, 16  64         ['conv2d_1[0][0]']
#  rmalization)                   )
#
#  batch_normalization_2 (BatchNo  (None, 128, 128, 16  64         ['batch_normalization_1[0][0]']
#  rmalization)                   )
#
#  activation_1 (Activation)      (None, 128, 128, 16  0           ['batch_normalization_2[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 64, 64, 16)   0           ['activation_1[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 64, 64, 32)   4640        ['max_pooling2d[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 64, 64, 32)  128         ['conv2d_2[0][0]']
#  rmalization)
#
#  activation_2 (Activation)      (None, 64, 64, 32)   0           ['batch_normalization_3[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 64, 64, 32)   9248        ['activation_2[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 64, 64, 32)  128         ['conv2d_3[0][0]']
#  rmalization)
#
#  batch_normalization_5 (BatchNo  (None, 64, 64, 32)  128         ['batch_normalization_4[0][0]']
#  rmalization)
#
#  activation_3 (Activation)      (None, 64, 64, 32)   0           ['batch_normalization_5[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 32, 32, 32)  0           ['activation_3[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 32, 32, 32)   9248        ['max_pooling2d_1[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 32, 32, 32)  128         ['conv2d_4[0][0]']
#  rmalization)
#
#  activation_4 (Activation)      (None, 32, 32, 32)   0           ['batch_normalization_6[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 32, 32, 32)   9248        ['activation_4[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 32, 32, 32)  128         ['conv2d_5[0][0]']
#  rmalization)
#
#  batch_normalization_8 (BatchNo  (None, 32, 32, 32)  128         ['batch_normalization_7[0][0]']
#  rmalization)
#
#  activation_5 (Activation)      (None, 32, 32, 32)   0           ['batch_normalization_8[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 16, 16, 32)  0           ['activation_5[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 16, 16, 64)   18496       ['max_pooling2d_2[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 16, 16, 64)  256         ['conv2d_6[0][0]']
#  rmalization)
#
#  activation_6 (Activation)      (None, 16, 16, 64)   0           ['batch_normalization_9[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 16, 16, 64)   36928       ['activation_6[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 16, 16, 64)  256         ['conv2d_7[0][0]']
#  ormalization)
#
#  batch_normalization_11 (BatchN  (None, 16, 16, 64)  256         ['batch_normalization_10[0][0]']
#  ormalization)
#
#  activation_7 (Activation)      (None, 16, 16, 64)   0           ['batch_normalization_11[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 8, 8, 64)    0           ['activation_7[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 8, 8, 128)    73856       ['max_pooling2d_3[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 8, 8, 128)   512         ['conv2d_8[0][0]']
#  ormalization)
#
#  activation_8 (Activation)      (None, 8, 8, 128)    0           ['batch_normalization_12[0][0]']
#
#  up_sampling2d (UpSampling2D)   (None, 16, 16, 128)  0           ['activation_8[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 16, 16, 128)  147584      ['up_sampling2d[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 16, 16, 128)  512        ['conv2d_9[0][0]']
#  ormalization)
#
#  activation_9 (Activation)      (None, 16, 16, 128)  0           ['batch_normalization_13[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 16, 16, 128)  147584      ['activation_9[0][0]']
#
#  batch_normalization_14 (BatchN  (None, 16, 16, 128)  512        ['conv2d_10[0][0]']
#  ormalization)
#
#  batch_normalization_15 (BatchN  (None, 16, 16, 128)  512        ['batch_normalization_14[0][0]']
#  ormalization)
#
#  activation_10 (Activation)     (None, 16, 16, 128)  0           ['batch_normalization_15[0][0]']
#
#  concatenate (Concatenate)      (None, 16, 16, 192)  0           ['activation_7[0][0]',
#                                                                   'activation_10[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 16, 16, 128)  221312      ['concatenate[0][0]']
#
#  batch_normalization_16 (BatchN  (None, 16, 16, 128)  512        ['conv2d_11[0][0]']
#  ormalization)
#
#  activation_11 (Activation)     (None, 16, 16, 128)  0           ['batch_normalization_16[0][0]']
#
#  up_sampling2d_1 (UpSampling2D)  (None, 32, 32, 128)  0          ['activation_11[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 32, 32, 128)  147584      ['up_sampling2d_1[0][0]']
#
#  batch_normalization_17 (BatchN  (None, 32, 32, 128)  512        ['conv2d_12[0][0]']
#  ormalization)
#
#  activation_12 (Activation)     (None, 32, 32, 128)  0           ['batch_normalization_17[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 32, 32, 128)  147584      ['activation_12[0][0]']
#
#  batch_normalization_18 (BatchN  (None, 32, 32, 128)  512        ['conv2d_13[0][0]']
#  ormalization)
#
#  batch_normalization_19 (BatchN  (None, 32, 32, 128)  512        ['batch_normalization_18[0][0]']
#  ormalization)
#
#  activation_13 (Activation)     (None, 32, 32, 128)  0           ['batch_normalization_19[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 32, 32, 160)  0           ['activation_5[0][0]',
#                                                                   'activation_13[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 32, 32, 128)  184448      ['concatenate_1[0][0]']
#
#  batch_normalization_20 (BatchN  (None, 32, 32, 128)  512        ['conv2d_14[0][0]']
#  ormalization)
#
#  activation_14 (Activation)     (None, 32, 32, 128)  0           ['batch_normalization_20[0][0]']
#
#  up_sampling2d_2 (UpSampling2D)  (None, 64, 64, 128)  0          ['activation_14[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 64, 64, 64)   73792       ['up_sampling2d_2[0][0]']
#
#  batch_normalization_21 (BatchN  (None, 64, 64, 64)  256         ['conv2d_15[0][0]']
#  ormalization)
#
#  activation_15 (Activation)     (None, 64, 64, 64)   0           ['batch_normalization_21[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 64, 64, 64)   36928       ['activation_15[0][0]']
#
#  batch_normalization_22 (BatchN  (None, 64, 64, 64)  256         ['conv2d_16[0][0]']
#  ormalization)
#
#  batch_normalization_23 (BatchN  (None, 64, 64, 64)  256         ['batch_normalization_22[0][0]']
#  ormalization)
#
#  activation_16 (Activation)     (None, 64, 64, 64)   0           ['batch_normalization_23[0][0]']
#
#  concatenate_2 (Concatenate)    (None, 64, 64, 96)   0           ['activation_3[0][0]',
#                                                                   'activation_16[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 64, 64, 64)   55360       ['concatenate_2[0][0]']
#
#  batch_normalization_24 (BatchN  (None, 64, 64, 64)  256         ['conv2d_17[0][0]']
#  ormalization)
#
#  activation_17 (Activation)     (None, 64, 64, 64)   0           ['batch_normalization_24[0][0]']
#
#  up_sampling2d_3 (UpSampling2D)  (None, 128, 128, 64  0          ['activation_17[0][0]']
#                                 )
#
#  conv2d_18 (Conv2D)             (None, 128, 128, 32  18464       ['up_sampling2d_3[0][0]']
#                                 )
#
#  batch_normalization_25 (BatchN  (None, 128, 128, 32  128        ['conv2d_18[0][0]']
#  ormalization)                  )
#
#  activation_18 (Activation)     (None, 128, 128, 32  0           ['batch_normalization_25[0][0]']
#                                 )
#
#  conv2d_19 (Conv2D)             (None, 128, 128, 32  9248        ['activation_18[0][0]']
#                                 )
#
#  batch_normalization_26 (BatchN  (None, 128, 128, 32  128        ['conv2d_19[0][0]']
#  ormalization)                  )
#
#  batch_normalization_27 (BatchN  (None, 128, 128, 32  128        ['batch_normalization_26[0][0]']
#  ormalization)                  )
#
#  activation_19 (Activation)     (None, 128, 128, 32  0           ['batch_normalization_27[0][0]']
#                                 )
#
#  concatenate_3 (Concatenate)    (None, 128, 128, 48  0           ['activation_1[0][0]',
#                                 )                                 'activation_19[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 128, 128, 32  13856       ['concatenate_3[0][0]']
#                                 )
#
#  batch_normalization_28 (BatchN  (None, 128, 128, 32  128        ['conv2d_20[0][0]']
#  ormalization)                  )
#
#  activation_20 (Activation)     (None, 128, 128, 32  0           ['batch_normalization_28[0][0]']
#                                 )
#
#  conv2d_21 (Conv2D)             (None, 128, 128, 1)  289         ['activation_20[0][0]']
#
#  activation_21 (Activation)     (None, 128, 128, 1)  0           ['conv2d_21[0][0]']
#
# ==================================================================================================
# Total params: 1,376,049
# Trainable params: 1,372,113
# Non-trainable params: 3,936
# __________________________________________________________________________________________________
