# %% [markdown]
# # **To Do**

# %% [markdown]
# Go to File > Open in playground mode
#
# **!!! Change Runtime to GPU !!!**
#
# **Go to Runtime > Change runtime type > Hardware accelerator:GPU **
#
# To run, go Runtime> Restart and run all

# %%
# !git clone https://github.com/twpkevin06222/Liver-Segmentation-Project-.git medical_imaging
# Out:
# Cloning into 'medical_imaging'...
# remote: Enumerating objects: 581, done.
# remote: Total 581 (delta 0), reused 0 (delta 0), pack-reused 581
# Receiving objects: 100% (581/581), 299.41 MiB | 46.51 MiB/s, done.
# Resolving deltas: 100% (181/181), done.

# %%
# !pip install nibabel
# Out:
# Requirement already satisfied: nibabel in /usr/local/lib/python3.10/dist-packages (4.0.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from nibabel) (1.23.5)
# Requirement already satisfied: packaging>=17.0 in /usr/local/lib/python3.10/dist-packages (from nibabel) (23.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from nibabel) (67.7.2)

# %% [markdown]
# # Imports

# %%
import h5py
import os
import cv2
from keras.layers import Input,Dense,Flatten,Dropout,Reshape,Conv2D,MaxPooling2D,UpSampling2D,Conv2DTranspose
from keras.layers import Activation
from keras.layers import BatchNormalization
from keras.models import Model,Sequential
from keras.callbacks import ModelCheckpoint
from keras.optimizers import Adadelta, RMSprop,SGD,Adam
from keras import regularizers
from keras import backend as K
import numpy as np
import scipy.misc
import numpy.random as rng
from PIL import Image, ImageDraw, ImageFont
from sklearn.utils import shuffle
import nibabel as nib #reading nifti images
import math
import glob
import matplotlib.pyplot as plt
# %matplotlib inline
#from read_data import load_images
from keras.layers import concatenate
from keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Dependencies

# %%
import tensorflow as tf
import keras
print('Tensorflow version:', tf.__version__)
print('Keras version:', keras.__version__)
# Out:
# Tensorflow version: 2.12.0
# Keras version: 2.12.0

# %% [markdown]
# ---

# %% [markdown]
# # Data Preprocessing
# Prepare data for input and data preprocessing

# %%
def three_to_two(path, label='FALSE'):
    ff = sorted(glob.glob(path))
    images =[]
    for f in range(len(ff)):
        a = nib.load(ff[f])
        a = a.get_data()
        for i in range(a.shape[2]):
            images.append(a[:,:,i])
    images = np.asarray(images)
    #images = images.reshape(-1, 128,128, 1) # dimension to feed into the network
    return images

def min_max_norm(images):
    m = np.max(images)
    mi = np.min(images)
    images = (images - mi)/ (m - mi)
    return images

def label_outliers(img_labels):
    img_labels[img_labels>1]=1
    img_labels[img_labels<0]=0
    return img_labels

#Image for training
images = three_to_two(path='medical_imaging/tmp/tmp_img/img_new/*')
x_data = min_max_norm(images)

#labels
img_labels = three_to_two(path='medical_imaging/tmp/tmp_img/img_new_label/*')
y_data = label_outliers(img_labels)

#Test Image
img_test = three_to_two(path='medical_imaging/tmp/tmp_img/test_img/*')
x_test = min_max_norm(img_test)

#Test Labels
label_test = three_to_two(path='medical_imaging/tmp/tmp_img/test_img_label/*')
y_test = label_outliers(label_test)
# Out:
# <ipython-input-5-281133919471>:6: DeprecationWarning: get_data() is deprecated in favor of get_fdata(), which has a more predictable return type. To obtain get_data() behavior going forward, use numpy.asanyarray(img.dataobj).
#
# * deprecated from version: 3.0
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 5.0
#   a = a.get_data()

# %%
def add_label_noise(labels, noise_ratio=0.70):
    flip_indices = np.random.choice(len(labels), size=int(len(labels) * noise_ratio), replace=False)
    # Flip the labels (0->1 and 1->0)
    labels[flip_indices] = 1 - labels[flip_indices]
    return labels

# Adding 1% noise to the training labels
y_data_noisy = add_label_noise(y_data.copy())  # Use .copy() to avoid modifying original y_data

# Now you can call the custom_augmentation function with the noisy labels (y_data_noisy) and x_data

# %% [markdown]
# Plot data w.r.t labels

# %%
#show 1st 20 slices

for i in range(20):
    fig, ax = plt.subplots(1,4, figsize = (8,4))
    ax[0].imshow(x_data[i], cmap='gray')
    ax[1].imshow(y_data_noisy[i], cmap='gray')
    ax[2].imshow(x_test[i], cmap='gray')
    ax[3].imshow(y_test[i], cmap='gray')

plt.show()

# %% [markdown]
# Reshape input data to feed into the network with
# shape (depth*#image, width, height, channel)

# %%
x_data = x_data[:,:,:,np.newaxis] # same as reshape (-1,128,128,1)
y_data_noisy = y_data_noisy[:,:,:,np.newaxis]
x_test = x_test[:,:,:,np.newaxis]
y_test = y_test[:,:,:,np.newaxis]

print('Dimension for training data:', x_data.shape)
print('Dimension for training data labels:', y_data_noisy.shape)
print('Dimension for test data:', x_test.shape)
print('Dimension for test data labels:', y_test.shape)
# Out:
# Dimension for training data: (3036, 128, 128, 1)
# Dimension for training data labels: (3036, 128, 128, 1)
# Dimension for test data: (735, 128, 128, 1)
# Dimension for test data labels: (735, 128, 128, 1)

# %% [markdown]
# Split data: 80% Training, 20% Validation

# %%
from sklearn.utils import shuffle

x_train, x_val, y_train, y_val = train_test_split(x_data, y_data_noisy, test_size = 0.2, random_state =42)
x_test, y_test = shuffle(x_test, y_test, random_state= 42)

# %% [markdown]
# Approximation of Dice Coefficient

# %%
import tensorflow as tf
from keras import backend as K
def jaccard_index(y_true, y_pred):
    intersection = K.sum(y_true * y_pred)
    union = K.sum(y_true) + K.sum(y_pred) - intersection
    return (intersection + K.epsilon()) / (union + K.epsilon())

def precision(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    return true_positives / (predicted_positives + K.epsilon())

def hausdorff_distance(y_true, y_pred):
    surface_distances = tf.reduce_sum(y_true * y_pred, axis=[1, 2]) / tf.reduce_sum(y_true + y_pred, axis=[1, 2])
    hausdorff_distance = tf.reduce_max(surface_distances)
    return hausdorff_distance

def specificity(y_true, y_pred):
    true_negatives = K.sum(K.round(K.clip((1 - y_true) * (1 - y_pred), 0, 1)))
    total_negatives = K.sum(K.round(K.clip(1 - y_true, 0, 1)))
    return true_negatives / (total_negatives + K.epsilon())

def sensitivity(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    total_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    return true_positives / (total_positives + K.epsilon())
def dice_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + K.epsilon()) / (K.sum(y_true_f) + K.sum(y_pred_f) + K.epsilon())

def sensitivity_specificity_loss(y_true, y_pred, beta=1):
    # Sensitivity = TP / (TP + FN)
    sensitivity = K.sum(y_true * y_pred) / (K.sum(y_true) + K.epsilon())

    # Specificity = TN / (TN + FP)
    specificity = K.sum((1 - y_true) * (1 - y_pred)) / (K.sum(1 - y_true) + K.epsilon())

    # Calculate sensitivity-specificity loss
    loss = 1 - (sensitivity**beta) * (specificity**(1 / beta))

    return loss

# %%
input_layer = Input(shape=x_train.shape[1:]) #Input(shape = (x, y, inChannel))

# %% [markdown]
# ---

# %% [markdown]
# # Network Topology

# %% [markdown]
# Toy Model 01

# %%
def conv_block(x_in, filters, batch_norm, kernel_size=(3,3)):
    x = Conv2D(filters, kernel_size, padding='same')(x_in)
    if batch_norm=='TRUE':
        x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Conv2D(filters, kernel_size, padding='same')(x)
    if batch_norm=='TRUE':
        x = BatchNormalization()(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    return x

def conv_2d(x_in, filters, batch_norm, kernel_size=(3,3),acti ='relu'):
    x = Conv2D(filters, kernel_size, padding='same')(x_in)
    if batch_norm=='TRUE':
        x=BatchNormalization()(x)
    x= Activation(acti)(x)
    return x

def pool(x_in, pool_size=(2, 2), type='Max'):
    if type=='Max':
        p = MaxPooling2D(pool_size)(x_in)
    return p

def up(x_in, filters, merge, batch_norm, size=(2,2)):
    u = UpSampling2D(size)(x_in)
    conv = conv_block(u, filters, batch_norm)
    merge=concatenate([merge, conv],axis=-1)
    return merge

def Unet_01(input_layer):
    conv1 = conv_block(input_layer, filters=16, batch_norm='TRUE')
    pool1 = pool(conv1)

    conv2 = conv_block(pool1, filters=32, batch_norm='TRUE')
    pool2 = pool(conv2)

    conv3 = conv_block(pool2, filters=32, batch_norm='TRUE')
    pool3 = pool(conv3)

    conv4 = conv_block(pool3, filters=64, batch_norm='TRUE')
    pool4 = pool(conv4)

    conv5 = conv_2d(pool4, filters=128, batch_norm='TRUE')

    up1 = up(conv5,filters=128, merge=conv4, batch_norm='TRUE')
    conv6 = conv_2d(up1, filters=128, batch_norm='TRUE')

    up2 = up(conv6, filters=128, merge=conv3, batch_norm='TRUE')
    conv7 = conv_2d(up2, filters=128, batch_norm='TRUE')

    up3 = up(conv7, filters=64, merge=conv2, batch_norm='TRUE')
    conv8 = conv_2d(up3, filters=64, batch_norm='TRUE')

    up4 = up(conv8, filters=32, merge=conv1, batch_norm='TRUE')
    conv9 = conv_2d(up4, filters=32, batch_norm='TRUE')

    conv10 = conv_2d(conv9, filters=1, batch_norm='FALSE', acti='sigmoid')

    output_layer = conv10
    model = Model(input_layer, output_layer)

    return model

# %% [markdown]
# Swtich for different network

# %%
model = Unet_01(input_layer)

# %% [markdown]
# Data Augmentation

# %%
def my_generator(x_train, y_train, batch_size):
    data_generator = ImageDataGenerator(
            width_shift_range=0.1,
            height_shift_range=0.1,
            rotation_range=10,
            zoom_range=0.1).flow(x_train, x_train, batch_size, seed=42)
    mask_generator = ImageDataGenerator(
            width_shift_range=0.1,
            height_shift_range=0.1,
            rotation_range=10,
            zoom_range=0.1).flow(y_train, y_train, batch_size, seed=42)
    while True:
        x_batch, _ = data_generator.next()
        y_batch, _ = mask_generator.next()
        yield x_batch, y_batch

# %%
image_batch, mask_batch = next(my_generator(x_train, y_train, 8))
fix, ax = plt.subplots(8,2, figsize=(8,20))
for i in range(8):
    ax[i,0].imshow(image_batch[i,:,:,0], cmap='gray')
    ax[i,1].imshow(mask_batch[i,:,:,0], cmap='gray')
plt.show()

# %%
model.compile(optimizer=Adam(1e-4), loss= sensitivity_specificity_loss, metrics=[dice_coef,jaccard_index,hausdorff_distance,precision,specificity,sensitivity])

# %% [markdown]
# Parameters

# %%
# def steps_per_epoch(sample, batch_size):
#     a = int(np.floor(sample/batch_size))
#     if a<200:
#         return 200
#     else:
#         return a

sample = len(x_data)
batch_size = 64
epochs = 20
steps_per_epoch = 200
#steps_per_epoch = int(np.floor(sample/batch_size))
#steps_per_epoch = steps_per_epoch(sample, batch_size)

print('Step per epoch: ', steps_per_epoch)
# Out:
# Step per epoch:  200

# %% [markdown]
# Set checkpoint

# %%
from keras.callbacks import LearningRateScheduler
weight_saver = ModelCheckpoint('seg.h5', monitor='val_dice_coef',
                                              save_best_only=True, save_weights_only=True)

lr_decay = LearningRateScheduler(lambda x: 1e-3 * 0.8 ** x)

# %%
from keras.callbacks import TensorBoard
import time

model_dir = 'logs/{}'.format(time.strftime("%H"+"%M"))
tensorboard = TensorBoard(log_dir= model_dir, histogram_freq=epochs, batch_size=batch_size, write_graph=True,
                          write_grads=False, write_images=True, embeddings_freq=0,
                          embeddings_layer_names=None, embeddings_metadata=None,
                          embeddings_data=None, update_freq='epoch')

write_time = time.strftime("%H"+"%M")
# Out:
# WARNING:tensorflow:`batch_size` is no longer needed in the `TensorBoard` Callback and will be ignored in TensorFlow 2.0.

# %% [markdown]
# ---

# %%
# !/opt/bin/nvidia-smi
# Out:
# Sun Aug 27 18:23:41 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.105.17   Driver Version: 525.105.17   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   52C    P0    29W /  70W |    401MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# +-----------------------------------------------------------------------------+

# %% [markdown]
# # Training

# %%
hist = model.fit_generator(my_generator(x_train, y_train, batch_size),
                           steps_per_epoch = steps_per_epoch,
                           validation_data = (x_val, y_val),
                           epochs=epochs, verbose=1,
                           callbacks = [weight_saver, lr_decay])
# Out:
# <ipython-input-22-714d6c19448a>:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   hist = model.fit_generator(my_generator(x_train, y_train, batch_size),
# Epoch 1/20
# 200/200 [==============================] - 101s 399ms/step - loss: 0.7199 - dice_coef: 0.6155 - jaccard_index: 0.4452 - hausdorff_distance: 0.4284 - precision: 0.6913 - specificity: 0.4295 - sensitivity: 0.6356 - val_loss: 0.7437 - val_dice_coef: 0.5092 - val_jaccard_index: 0.3418 - val_hausdorff_distance: 0.3215 - val_precision: 0.7183 - val_specificity: 0.9274 - val_sensitivity: 0.0818 - lr: 0.0010
# Epoch 2/20
# 200/200 [==============================] - 70s 350ms/step - loss: 0.7149 - dice_coef: 0.6203 - jaccard_index: 0.4504 - hausdorff_distance: 0.4650 - precision: 0.6996 - specificity: 0.5060 - sensitivity: 0.5643 - val_loss: 0.7296 - val_dice_coef: 0.5403 - val_jaccard_index: 0.3713 - val_hausdorff_distance: 0.4907 - val_precision: 0.7137 - val_specificity: 0.6133 - val_sensitivity: 0.4426 - lr: 8.0000e-04
# Epoch 3/20
# 200/200 [==============================] - 69s 345ms/step - loss: 0.7209 - dice_coef: 0.6137 - jaccard_index: 0.4435 - hausdorff_distance: 0.4761 - precision: 0.6927 - specificity: 0.5031 - sensitivity: 0.5534 - val_loss: 0.8923 - val_dice_coef: 0.2049 - val_jaccard_index: 0.1144 - val_hausdorff_distance: 0.2688 - val_precision: 0.7222 - val_specificity: 0.8985 - val_sensitivity: 0.1213 - lr: 6.4000e-04
# Epoch 4/20
# 200/200 [==============================] - 69s 346ms/step - loss: 0.7179 - dice_coef: 0.6211 - jaccard_index: 0.4513 - hausdorff_distance: 0.4660 - precision: 0.6934 - specificity: 0.4947 - sensitivity: 0.5694 - val_loss: 0.7231 - val_dice_coef: 0.7004 - val_jaccard_index: 0.5409 - val_hausdorff_distance: 0.4789 - val_precision: 0.7159 - val_specificity: 0.3896 - val_sensitivity: 0.7026 - lr: 5.1200e-04
# Epoch 5/20
# 200/200 [==============================] - 68s 341ms/step - loss: 0.7150 - dice_coef: 0.6199 - jaccard_index: 0.4499 - hausdorff_distance: 0.4677 - precision: 0.6975 - specificity: 0.5061 - sensitivity: 0.5624 - val_loss: 0.7215 - val_dice_coef: 0.6889 - val_jaccard_index: 0.5267 - val_hausdorff_distance: 0.4832 - val_precision: 0.7152 - val_specificity: 0.4159 - val_sensitivity: 0.6677 - lr: 4.0960e-04
# Epoch 6/20
# 200/200 [==============================] - 69s 344ms/step - loss: 0.7137 - dice_coef: 0.6190 - jaccard_index: 0.4491 - hausdorff_distance: 0.4799 - precision: 0.6982 - specificity: 0.5103 - sensitivity: 0.5595 - val_loss: 0.7119 - val_dice_coef: 0.6843 - val_jaccard_index: 0.5212 - val_hausdorff_distance: 0.4864 - val_precision: 0.7199 - val_specificity: 0.4440 - val_sensitivity: 0.6503 - lr: 3.2768e-04
# Epoch 7/20
# 200/200 [==============================] - 69s 344ms/step - loss: 0.7093 - dice_coef: 0.6283 - jaccard_index: 0.4591 - hausdorff_distance: 0.4808 - precision: 0.7004 - specificity: 0.5040 - sensitivity: 0.5748 - val_loss: 0.7511 - val_dice_coef: 0.7383 - val_jaccard_index: 0.5870 - val_hausdorff_distance: 0.4907 - val_precision: 0.7140 - val_specificity: 0.3199 - val_sensitivity: 0.7728 - lr: 2.6214e-04
# Epoch 8/20
# 200/200 [==============================] - 69s 344ms/step - loss: 0.7067 - dice_coef: 0.6274 - jaccard_index: 0.4584 - hausdorff_distance: 0.4867 - precision: 0.7017 - specificity: 0.5111 - sensitivity: 0.5719 - val_loss: 0.7103 - val_dice_coef: 0.6554 - val_jaccard_index: 0.4887 - val_hausdorff_distance: 0.4869 - val_precision: 0.7198 - val_specificity: 0.4776 - val_sensitivity: 0.6088 - lr: 2.0972e-04
# Epoch 9/20
# 200/200 [==============================] - 68s 342ms/step - loss: 0.7030 - dice_coef: 0.6272 - jaccard_index: 0.4581 - hausdorff_distance: 0.4913 - precision: 0.7057 - specificity: 0.5203 - sensitivity: 0.5685 - val_loss: 0.7797 - val_dice_coef: 0.7610 - val_jaccard_index: 0.6161 - val_hausdorff_distance: 0.4984 - val_precision: 0.7121 - val_specificity: 0.2663 - val_sensitivity: 0.8239 - lr: 1.6777e-04
# Epoch 10/20
# 200/200 [==============================] - 69s 344ms/step - loss: 0.6956 - dice_coef: 0.6335 - jaccard_index: 0.4648 - hausdorff_distance: 0.4935 - precision: 0.7095 - specificity: 0.5270 - sensitivity: 0.5752 - val_loss: 0.7127 - val_dice_coef: 0.6918 - val_jaccard_index: 0.5307 - val_hausdorff_distance: 0.4917 - val_precision: 0.7206 - val_specificity: 0.4281 - val_sensitivity: 0.6713 - lr: 1.3422e-04
# Epoch 11/20
# 200/200 [==============================] - 68s 342ms/step - loss: 0.6935 - dice_coef: 0.6360 - jaccard_index: 0.4676 - hausdorff_distance: 0.4940 - precision: 0.7124 - specificity: 0.5283 - sensitivity: 0.5771 - val_loss: 0.7917 - val_dice_coef: 0.7456 - val_jaccard_index: 0.5961 - val_hausdorff_distance: 0.4971 - val_precision: 0.7047 - val_specificity: 0.2601 - val_sensitivity: 0.7978 - lr: 1.0737e-04
# Epoch 12/20
# 200/200 [==============================] - 69s 343ms/step - loss: 0.6920 - dice_coef: 0.6352 - jaccard_index: 0.4665 - hausdorff_distance: 0.4949 - precision: 0.7124 - specificity: 0.5324 - sensitivity: 0.5754 - val_loss: 0.7098 - val_dice_coef: 0.6588 - val_jaccard_index: 0.4931 - val_hausdorff_distance: 0.4925 - val_precision: 0.7197 - val_specificity: 0.4739 - val_sensitivity: 0.6131 - lr: 8.5899e-05
# Epoch 13/20
# 200/200 [==============================] - 69s 344ms/step - loss: 0.6890 - dice_coef: 0.6370 - jaccard_index: 0.4687 - hausdorff_distance: 0.4956 - precision: 0.7150 - specificity: 0.5363 - sensitivity: 0.5768 - val_loss: 0.7516 - val_dice_coef: 0.7479 - val_jaccard_index: 0.5991 - val_hausdorff_distance: 0.4964 - val_precision: 0.7167 - val_specificity: 0.3149 - val_sensitivity: 0.7881 - lr: 6.8719e-05
# Epoch 14/20
# 200/200 [==============================] - 69s 343ms/step - loss: 0.6847 - dice_coef: 0.6409 - jaccard_index: 0.4725 - hausdorff_distance: 0.4958 - precision: 0.7196 - specificity: 0.5409 - sensitivity: 0.5799 - val_loss: 0.7134 - val_dice_coef: 0.6802 - val_jaccard_index: 0.5174 - val_hausdorff_distance: 0.4952 - val_precision: 0.7197 - val_specificity: 0.4414 - val_sensitivity: 0.6509 - lr: 5.4976e-05
# Epoch 15/20
# 200/200 [==============================] - 69s 346ms/step - loss: 0.6852 - dice_coef: 0.6426 - jaccard_index: 0.4745 - hausdorff_distance: 0.4964 - precision: 0.7175 - specificity: 0.5362 - sensitivity: 0.5843 - val_loss: 0.7146 - val_dice_coef: 0.6700 - val_jaccard_index: 0.5058 - val_hausdorff_distance: 0.4943 - val_precision: 0.7183 - val_specificity: 0.4514 - val_sensitivity: 0.6342 - lr: 4.3980e-05
# Epoch 16/20
# 200/200 [==============================] - 68s 341ms/step - loss: 0.6848 - dice_coef: 0.6415 - jaccard_index: 0.4734 - hausdorff_distance: 0.4964 - precision: 0.7193 - specificity: 0.5392 - sensitivity: 0.5814 - val_loss: 0.7123 - val_dice_coef: 0.6774 - val_jaccard_index: 0.5143 - val_hausdorff_distance: 0.4955 - val_precision: 0.7199 - val_specificity: 0.4468 - val_sensitivity: 0.6458 - lr: 3.5184e-05
# Epoch 17/20
# 200/200 [==============================] - 69s 343ms/step - loss: 0.6828 - dice_coef: 0.6440 - jaccard_index: 0.4761 - hausdorff_distance: 0.4962 - precision: 0.7199 - specificity: 0.5396 - sensitivity: 0.5847 - val_loss: 0.7195 - val_dice_coef: 0.6960 - val_jaccard_index: 0.5359 - val_hausdorff_distance: 0.4951 - val_precision: 0.7187 - val_specificity: 0.4132 - val_sensitivity: 0.6812 - lr: 2.8147e-05
# Epoch 18/20
# 200/200 [==============================] - 69s 343ms/step - loss: 0.6811 - dice_coef: 0.6430 - jaccard_index: 0.4748 - hausdorff_distance: 0.4968 - precision: 0.7179 - specificity: 0.5436 - sensitivity: 0.5844 - val_loss: 0.7172 - val_dice_coef: 0.6929 - val_jaccard_index: 0.5323 - val_hausdorff_distance: 0.4960 - val_precision: 0.7196 - val_specificity: 0.4208 - val_sensitivity: 0.6747 - lr: 2.2518e-05
# Epoch 19/20
# 200/200 [==============================] - 69s 343ms/step - loss: 0.6801 - dice_coef: 0.6444 - jaccard_index: 0.4767 - hausdorff_distance: 0.4965 - precision: 0.7227 - specificity: 0.5454 - sensitivity: 0.5836 - val_loss: 0.7245 - val_dice_coef: 0.7028 - val_jaccard_index: 0.5439 - val_hausdorff_distance: 0.4966 - val_precision: 0.7174 - val_specificity: 0.3974 - val_sensitivity: 0.6952 - lr: 1.8014e-05
# Epoch 20/20
# 200/200 [==============================] - 69s 343ms/step - loss: 0.6794 - dice_coef: 0.6434 - jaccard_index: 0.4755 - hausdorff_distance: 0.4966 - precision: 0.7206 - specificity: 0.5465 - sensitivity: 0.5833 - val_loss: 0.7270 - val_dice_coef: 0.7051 - val_jaccard_index: 0.5466 - val_hausdorff_distance: 0.4967 - val_precision: 0.7168 - val_specificity: 0.3911 - val_sensitivity: 0.7002 - lr: 1.4412e-05

# %%
model.load_weights('seg.h5')

# %% [markdown]
# ---

# %% [markdown]
# # Results

# %% [markdown]
# Learning Rate Plot

# %%
plt.plot(hist.history['lr'], color='b')
plt.xlabel("epochs")
plt.ylabel("Learning Rate")
plt.grid(linestyle='dotted')
plt.show()

# %% [markdown]
# ***

# %% [markdown]
# Loss and Dice Coefficient Plot

# %%
plt.plot(hist.history['loss'], color='b', label='Training')
plt.plot(hist.history['val_loss'], color='r', label='Validation')
plt.legend(loc='upper right')
plt.xlabel("epochs")
plt.ylabel("Loss")
plt.grid(linestyle='dotted')
plt.show()

import matplotlib.pyplot as plt

# Assuming you have a `hist` dictionary with metrics like 'loss', 'val_loss', 'dice_coef', 'val_dice_coef',
# 'specificity', 'val_specificity', 'sensitivity', 'val_sensitivity', 'precision', 'val_precision',
# 'jaccard_index', 'val_jaccard_index', 'hausdorff_distance', 'val_hausdorff_distance', etc.

# Plot all metrics in one graph
plt.figure(figsize=(12, 8))

# Dice Coefficient
plt.plot(hist.history['dice_coef'], color='b', label='Training Dice Coefficient')
plt.plot(hist.history['val_dice_coef'], color='r', label='Validation Dice Coefficient')

# Specificity
plt.plot(hist.history['specificity'], color='g', label='Training Specificity')
plt.plot(hist.history['val_specificity'], color='m', label='Validation Specificity')

# Sensitivity (Recall)
plt.plot(hist.history['sensitivity'], color='c', label='Training Sensitivity')
plt.plot(hist.history['val_sensitivity'], color='y', label='Validation Sensitivity')

# Precision
plt.plot(hist.history['precision'], color='k', label='Training Precision')
plt.plot(hist.history['val_precision'], color='purple', label='Validation Precision')

# Jaccard Index (Intersection over Union)
plt.plot(hist.history['jaccard_index'], color='orange', label='Training Jaccard Index')
plt.plot(hist.history['val_jaccard_index'], color='pink', label='Validation Jaccard Index')

# Hausdorff Distance
plt.plot(hist.history['hausdorff_distance'], color='darkgreen', label='Training Hausdorff Distance')
plt.plot(hist.history['val_hausdorff_distance'], color='olive', label='Validation Hausdorff Distance')

plt.xlabel("Epochs")
plt.ylabel("Metrics")
plt.legend(loc='lower right')
plt.grid(linestyle='dotted')
plt.title("Metrics over Epochs")
plt.show()

# %%
# To run tensorboard
print('To view tensorboard, put this in your command line: \n tensorboard --log=logs/{}/'.format(write_time))
# Out:
# To view tensorboard, put this in your command line:
#  tensorboard --log=logs/1823/

# %%
# !rm -rf ngrok-stable-linux-amd64.zip
# !rm -rf ngrok
# !wget https://bin.equinox.io/c/4VmDzA7iaHb/ngrok-stable-linux-amd64.zip
# !unzip ngrok-stable-linux-amd64.zip
#!rm -f log/*   # Delete this if you want to keep the logs of the old runs
LOG_DIR = 'logs/{}'.format(write_time)
get_ipython().system_raw(
    'tensorboard --logdir {} --host 0.0.0.0 --port 6006 &'
    .format(LOG_DIR)
)
get_ipython().system_raw('./ngrok http 6006 &')
! curl -s http://localhost:4040/api/tunnels | python3 -c \
    "import sys, json; print(json.load(sys.stdin)['tunnels'][0]['public_url'])"
# Out:
# --2023-08-27 18:48:14--  https://bin.equinox.io/c/4VmDzA7iaHb/ngrok-stable-linux-amd64.zip
# Resolving bin.equinox.io (bin.equinox.io)... 18.205.222.128, 54.161.241.46, 54.237.133.81, ...
# Connecting to bin.equinox.io (bin.equinox.io)|18.205.222.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 13921656 (13M) [application/octet-stream]
# Saving to: ‘ngrok-stable-linux-amd64.zip’
#
# ngrok-stable-linux- 100%[===================>]  13.28M  41.8MB/s    in 0.3s
#
# 2023-08-27 18:48:15 (41.8 MB/s) - ‘ngrok-stable-linux-amd64.zip’ saved [13921656/13921656]
#
# Archive:  ngrok-stable-linux-amd64.zip
#   inflating: ngrok
# https://ae9b-35-222-69-242.ngrok.io

# %%
# Assuming you have already trained your model and loaded the test data in `x_test` and `y_test`

# Evaluate the model on the test data
test_eval = model.evaluate(x_test, y_test, verbose=1)

# Extract the test accuracy from the evaluation results
test_accuracy = test_eval[1]

# Print the test accuracy
print('Test accuracy:', test_accuracy)
# Out:
# 23/23 [==============================] - 5s 158ms/step - loss: 0.9986 - dice_coef: 9.8507e-04 - jaccard_index: 4.9284e-04 - hausdorff_distance: 0.0049 - precision: 2.4454e-04 - specificity: 0.8658 - sensitivity: 5.1749e-04
# Test accuracy: 0.0009850735077634454

# %% [markdown]
# ---

# %% [markdown]
# # Prediction

# %%
y_pred = model.predict(x_test)
for i in range(0,20,2):
    fig, ax = plt.subplots(1,3,figsize=(12,6))
    ax[0].imshow(x_test[i,:,:,0], cmap='gray')
    ax[1].imshow(y_test[i,:,:,0], cmap='viridis')
    ax[2].imshow(y_pred[i,:,:,0], cmap='viridis')
plt.show()
# Out:
# 23/23 [==============================] - 1s 46ms/step

# %% [markdown]
# ---

# %% [markdown]
# # Appendix

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 128, 128, 1  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 128, 128, 16  160         ['input_1[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 128, 128, 16  64         ['conv2d[0][0]']
#  alization)                     )
#
#  activation (Activation)        (None, 128, 128, 16  0           ['batch_normalization[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 128, 128, 16  2320        ['activation[0][0]']
#                                 )
#
#  batch_normalization_1 (BatchNo  (None, 128, 128, 16  64         ['conv2d_1[0][0]']
#  rmalization)                   )
#
#  batch_normalization_2 (BatchNo  (None, 128, 128, 16  64         ['batch_normalization_1[0][0]']
#  rmalization)                   )
#
#  activation_1 (Activation)      (None, 128, 128, 16  0           ['batch_normalization_2[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 64, 64, 16)   0           ['activation_1[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 64, 64, 32)   4640        ['max_pooling2d[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 64, 64, 32)  128         ['conv2d_2[0][0]']
#  rmalization)
#
#  activation_2 (Activation)      (None, 64, 64, 32)   0           ['batch_normalization_3[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 64, 64, 32)   9248        ['activation_2[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 64, 64, 32)  128         ['conv2d_3[0][0]']
#  rmalization)
#
#  batch_normalization_5 (BatchNo  (None, 64, 64, 32)  128         ['batch_normalization_4[0][0]']
#  rmalization)
#
#  activation_3 (Activation)      (None, 64, 64, 32)   0           ['batch_normalization_5[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 32, 32, 32)  0           ['activation_3[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 32, 32, 32)   9248        ['max_pooling2d_1[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 32, 32, 32)  128         ['conv2d_4[0][0]']
#  rmalization)
#
#  activation_4 (Activation)      (None, 32, 32, 32)   0           ['batch_normalization_6[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 32, 32, 32)   9248        ['activation_4[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 32, 32, 32)  128         ['conv2d_5[0][0]']
#  rmalization)
#
#  batch_normalization_8 (BatchNo  (None, 32, 32, 32)  128         ['batch_normalization_7[0][0]']
#  rmalization)
#
#  activation_5 (Activation)      (None, 32, 32, 32)   0           ['batch_normalization_8[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 16, 16, 32)  0           ['activation_5[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 16, 16, 64)   18496       ['max_pooling2d_2[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 16, 16, 64)  256         ['conv2d_6[0][0]']
#  rmalization)
#
#  activation_6 (Activation)      (None, 16, 16, 64)   0           ['batch_normalization_9[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 16, 16, 64)   36928       ['activation_6[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 16, 16, 64)  256         ['conv2d_7[0][0]']
#  ormalization)
#
#  batch_normalization_11 (BatchN  (None, 16, 16, 64)  256         ['batch_normalization_10[0][0]']
#  ormalization)
#
#  activation_7 (Activation)      (None, 16, 16, 64)   0           ['batch_normalization_11[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 8, 8, 64)    0           ['activation_7[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 8, 8, 128)    73856       ['max_pooling2d_3[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 8, 8, 128)   512         ['conv2d_8[0][0]']
#  ormalization)
#
#  activation_8 (Activation)      (None, 8, 8, 128)    0           ['batch_normalization_12[0][0]']
#
#  up_sampling2d (UpSampling2D)   (None, 16, 16, 128)  0           ['activation_8[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 16, 16, 128)  147584      ['up_sampling2d[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 16, 16, 128)  512        ['conv2d_9[0][0]']
#  ormalization)
#
#  activation_9 (Activation)      (None, 16, 16, 128)  0           ['batch_normalization_13[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 16, 16, 128)  147584      ['activation_9[0][0]']
#
#  batch_normalization_14 (BatchN  (None, 16, 16, 128)  512        ['conv2d_10[0][0]']
#  ormalization)
#
#  batch_normalization_15 (BatchN  (None, 16, 16, 128)  512        ['batch_normalization_14[0][0]']
#  ormalization)
#
#  activation_10 (Activation)     (None, 16, 16, 128)  0           ['batch_normalization_15[0][0]']
#
#  concatenate (Concatenate)      (None, 16, 16, 192)  0           ['activation_7[0][0]',
#                                                                   'activation_10[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 16, 16, 128)  221312      ['concatenate[0][0]']
#
#  batch_normalization_16 (BatchN  (None, 16, 16, 128)  512        ['conv2d_11[0][0]']
#  ormalization)
#
#  activation_11 (Activation)     (None, 16, 16, 128)  0           ['batch_normalization_16[0][0]']
#
#  up_sampling2d_1 (UpSampling2D)  (None, 32, 32, 128)  0          ['activation_11[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 32, 32, 128)  147584      ['up_sampling2d_1[0][0]']
#
#  batch_normalization_17 (BatchN  (None, 32, 32, 128)  512        ['conv2d_12[0][0]']
#  ormalization)
#
#  activation_12 (Activation)     (None, 32, 32, 128)  0           ['batch_normalization_17[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 32, 32, 128)  147584      ['activation_12[0][0]']
#
#  batch_normalization_18 (BatchN  (None, 32, 32, 128)  512        ['conv2d_13[0][0]']
#  ormalization)
#
#  batch_normalization_19 (BatchN  (None, 32, 32, 128)  512        ['batch_normalization_18[0][0]']
#  ormalization)
#
#  activation_13 (Activation)     (None, 32, 32, 128)  0           ['batch_normalization_19[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 32, 32, 160)  0           ['activation_5[0][0]',
#                                                                   'activation_13[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 32, 32, 128)  184448      ['concatenate_1[0][0]']
#
#  batch_normalization_20 (BatchN  (None, 32, 32, 128)  512        ['conv2d_14[0][0]']
#  ormalization)
#
#  activation_14 (Activation)     (None, 32, 32, 128)  0           ['batch_normalization_20[0][0]']
#
#  up_sampling2d_2 (UpSampling2D)  (None, 64, 64, 128)  0          ['activation_14[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 64, 64, 64)   73792       ['up_sampling2d_2[0][0]']
#
#  batch_normalization_21 (BatchN  (None, 64, 64, 64)  256         ['conv2d_15[0][0]']
#  ormalization)
#
#  activation_15 (Activation)     (None, 64, 64, 64)   0           ['batch_normalization_21[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 64, 64, 64)   36928       ['activation_15[0][0]']
#
#  batch_normalization_22 (BatchN  (None, 64, 64, 64)  256         ['conv2d_16[0][0]']
#  ormalization)
#
#  batch_normalization_23 (BatchN  (None, 64, 64, 64)  256         ['batch_normalization_22[0][0]']
#  ormalization)
#
#  activation_16 (Activation)     (None, 64, 64, 64)   0           ['batch_normalization_23[0][0]']
#
#  concatenate_2 (Concatenate)    (None, 64, 64, 96)   0           ['activation_3[0][0]',
#                                                                   'activation_16[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 64, 64, 64)   55360       ['concatenate_2[0][0]']
#
#  batch_normalization_24 (BatchN  (None, 64, 64, 64)  256         ['conv2d_17[0][0]']
#  ormalization)
#
#  activation_17 (Activation)     (None, 64, 64, 64)   0           ['batch_normalization_24[0][0]']
#
#  up_sampling2d_3 (UpSampling2D)  (None, 128, 128, 64  0          ['activation_17[0][0]']
#                                 )
#
#  conv2d_18 (Conv2D)             (None, 128, 128, 32  18464       ['up_sampling2d_3[0][0]']
#                                 )
#
#  batch_normalization_25 (BatchN  (None, 128, 128, 32  128        ['conv2d_18[0][0]']
#  ormalization)                  )
#
#  activation_18 (Activation)     (None, 128, 128, 32  0           ['batch_normalization_25[0][0]']
#                                 )
#
#  conv2d_19 (Conv2D)             (None, 128, 128, 32  9248        ['activation_18[0][0]']
#                                 )
#
#  batch_normalization_26 (BatchN  (None, 128, 128, 32  128        ['conv2d_19[0][0]']
#  ormalization)                  )
#
#  batch_normalization_27 (BatchN  (None, 128, 128, 32  128        ['batch_normalization_26[0][0]']
#  ormalization)                  )
#
#  activation_19 (Activation)     (None, 128, 128, 32  0           ['batch_normalization_27[0][0]']
#                                 )
#
#  concatenate_3 (Concatenate)    (None, 128, 128, 48  0           ['activation_1[0][0]',
#                                 )                                 'activation_19[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 128, 128, 32  13856       ['concatenate_3[0][0]']
#                                 )
#
#  batch_normalization_28 (BatchN  (None, 128, 128, 32  128        ['conv2d_20[0][0]']
#  ormalization)                  )
#
#  activation_20 (Activation)     (None, 128, 128, 32  0           ['batch_normalization_28[0][0]']
#                                 )
#
#  conv2d_21 (Conv2D)             (None, 128, 128, 1)  289         ['activation_20[0][0]']
#
#  activation_21 (Activation)     (None, 128, 128, 1)  0           ['conv2d_21[0][0]']
#
# ==================================================================================================
# Total params: 1,376,049
# Trainable params: 1,372,113
# Non-trainable params: 3,936
# __________________________________________________________________________________________________

# %% [markdown]
# # Reference

# %% [markdown]
# *   https://www.kaggle.com/toregil/a-lung-u-net-in-keras
# *   https://github.com/jocicmarko/ultrasound-nerve-segmentation
